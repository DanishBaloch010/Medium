# %% [markdown]
# # SQL 'order by' and 'group by' clause in Python.
# ## sorting the dataset and organizing in clusters.

# %% [markdown]
# This notebook is a guide to perform sorting on dataset. further it explains how to aggregate the data into clusters using group by. Than perform aggregated functions on these clustered data.

# %% [markdown]
# ## Importing CSV data using pandas

# %%
import pandas as pd

data =  pd.read_csv(r'BankWages.csv')

# %%
display(data)
# Out:
#       id     job  education  gender minority
# 0      1  manage         15    male       no
# 1      2   admin         16    male       no
# 2      3   admin         12  female       no
# 3      4   admin          8  female       no
# 4      5   admin         15    male       no
# ..   ...     ...        ...     ...      ...
# 469  470   admin         12    male      yes
# 470  471   admin         15    male      yes
# 471  472   admin         15    male       no
# 472  473   admin         12  female       no
# 473  474   admin         12  female       no
#
# [474 rows x 5 columns]

# %% [markdown]
# ### to display whole data frame in string format but with no formatting.

# %%
display(data.to_string())
# Out:
# '      id        job  education  gender minority\n0      1     manage         15    male       no\n1      2      admin         16    male       no\n2      3      admin         12  female       no\n3      4      admin          8  female       no\n4      5      admin         15    male       no\n5      6      admin         15    male       no\n6      7      admin         15    male       no\n7      8      admin         12  female       no\n8      9      admin         15  female       no\n9     10      admin         12  female       no\n10    11      admin         16  female       no\n11    12      admin          8    male      yes\n12    13      admin         15    male      yes\n13    14      admin         15  female      yes\n14    15      admin         12    male       no\n15    16      admin         12    male       no\n16    17      admin         15    male       no\n17    18     manage         16    male       no\n18    19      admin         12    male       no\n19    20      admin         12  female       no\n20    21      admin         16  female       no\n21    22      admin         12    male      yes\n22    23      admin         15  female      yes\n23    24      admin         12  female      yes\n24    25      admin         15  female      yes\n25    26      admin         15    male       no\n26    27     manage         19    male       no\n27    28      admin         15    male       no\n28    29     manage         19    male       no\n29    30      admin         15    male       no\n30    31      admin         12    male       no\n31    32     manage         19    male       no\n32    33      admin         15    male       no\n33    34     manage         19    male       no\n34    35     manage         17    male       no\n35    36      admin          8  female       no\n36    37      admin         12    male      yes\n37    38      admin         15    male      yes\n38    39      admin         16    male      yes\n39    40      admin         15  female      yes\n40    41      admin         12  female      yes\n41    42      admin         15    male       no\n42    43      admin         12    male       no\n43    44      admin          8    male       no\n44    45  custodial         12    male       no\n45    46      admin         15  female       no\n46    47      admin         12  female       no\n47    48  custodial         12    male       no\n48    49      admin         15    male       no\n49    50     manage         16    male       no\n50    51      admin         12    male       no\n51    52      admin         15    male       no\n52    53     manage         18    male       no\n53    54      admin         12    male       no\n54    55      admin         12    male       no\n55    56      admin         15    male       no\n56    57      admin         15    male       no\n57    58      admin         15  female       no\n58    59      admin         15    male      yes\n59    60      admin         12    male      yes\n60    61      admin          8    male      yes\n61    62     manage         16    male       no\n62    63     manage         17    male       no\n63    64     manage         16    male       no\n64    65      admin          8    male       no\n65    66     manage         19    male       no\n66    67     manage         16    male       no\n67    68     manage         16    male       no\n68    69     manage         16    male       no\n69    70      admin         15    male       no\n70    71     manage         17    male       no\n71    72      admin         16  female       no\n72    73      admin         12  female       no\n73    74      admin         15  female       no\n74    75      admin         15  female       no\n75    76      admin         15  female       no\n76    77      admin         12  female       no\n77    78      admin         12  female       no\n78    79      admin         16  female       no\n79    80      admin         16  female       no\n80    81      admin         12 ...

# %% [markdown]
# ### to display whole data frame in string format but with formatting.

# %%
print(data.to_markdown())
# Out:
# |     |   id | job       |   education | gender   | minority   |
# |----:|-----:|:----------|------------:|:---------|:-----------|
# |   0 |    1 | manage    |          15 | male     | no         |
# |   1 |    2 | admin     |          16 | male     | no         |
# |   2 |    3 | admin     |          12 | female   | no         |
# |   3 |    4 | admin     |           8 | female   | no         |
# |   4 |    5 | admin     |          15 | male     | no         |
# |   5 |    6 | admin     |          15 | male     | no         |
# |   6 |    7 | admin     |          15 | male     | no         |
# |   7 |    8 | admin     |          12 | female   | no         |
# |   8 |    9 | admin     |          15 | female   | no         |
# |   9 |   10 | admin     |          12 | female   | no         |
# |  10 |   11 | admin     |          16 | female   | no         |
# |  11 |   12 | admin     |           8 | male     | yes        |
# |  12 |   13 | admin     |          15 | male     | yes        |
# |  13 |   14 | admin     |          15 | female   | yes        |
# |  14 |   15 | admin     |          12 | male     | no         |
# |  15 |   16 | admin     |          12 | male     | no         |
# |  16 |   17 | admin     |          15 | male     | no         |
# |  17 |   18 | manage    |          16 | male     | no         |
# |  18 |   19 | admin     |          12 | male     | no         |
# |  19 |   20 | admin     |          12 | female   | no         |
# |  20 |   21 | admin     |          16 | female   | no         |
# |  21 |   22 | admin     |          12 | male     | yes        |
# |  22 |   23 | admin     |          15 | female   | yes        |
# |  23 |   24 | admin     |          12 | female   | yes        |
# |  24 |   25 | admin     |          15 | female   | yes        |
# |  25 |   26 | admin     |          15 | male     | no         |
# |  26 |   27 | manage    |          19 | male     | no         |
# |  27 |   28 | admin     |          15 | male     | no         |
# |  28 |   29 | manage    |          19 | male     | no         |
# |  29 |   30 | admin     |          15 | male     | no         |
# |  30 |   31 | admin     |          12 | male     | no         |
# |  31 |   32 | manage    |          19 | male     | no         |
# |  32 |   33 | admin     |          15 | male     | no         |
# |  33 |   34 | manage    |          19 | male     | no         |
# |  34 |   35 | manage    |          17 | male     | no         |
# |  35 |   36 | admin     |           8 | female   | no         |
# |  36 |   37 | admin     |          12 | male     | yes        |
# |  37 |   38 | admin     |          15 | male     | yes        |
# |  38 |   39 | admin     |          16 | male     | yes        |
# |  39 |   40 | admin     |          15 | female   | yes        |
# |  40 |   41 | admin     |          12 | female   | yes        |
# |  41 |   42 | admin     |          15 | male     | no         |
# |  42 |   43 | admin     |          12 | male     | no         |
# |  43 |   44 | admin     |           8 | male     | no         |
# |  44 |   45 | custodial |          12 | male     | no         |
# |  45 |   46 | admin     |          15 | female   | no         |
# |  46 |   47 | admin     |          12 | female   | no         |
# |  47 |   48 | custodial |          12 | male     | no         |
# |  48 |   49 | admin     |          15 | male     | no         |
# |  49 |   50 | manage    |          16 | male     | no         |
# |  50 |   51 | admin     |          12 | male     | no         |
# |  51 |   52 | admin     |          15 | male     | no         |
# |  52 |   53 | manage    |          18 | male     | no         |
# |  53 |   54 | admin     |          12 | male     | no         |
# |  54 |   55 | admin     |          12 | male     | no         |
# |  55 |   56 | admin     |          15 | male     | no         |
# |  56 |   57 | admin     |          15 | male     | no         |
# |  57 |   58 | admin     |          15 | female   | no         |
# |  58 |   59 | admin     |          15 | male     | yes        |
# |  59 |   60 | admin     |          12 | male     | yes        |
# |  60 |   61 | admin     |           8 | male     | yes        |
# |  61 |   62 | manage    |          16 | male     | no         |
# |  62 |   63 | manage    |          17 | male     | no         |
# |  63 |   64 | manage    |          16 | male     | no         |
# |  64 |   65 | admin     |           8 | male     | no         |
# |  65 |   66 | manage    |          19 | male     | no         |
# |  66 |   67 | manage    |          16 | male     | no         |
# |  67 |   68 | manage    |          16 | male     | no         |
# |  68 |   69 | manage    |          16 | male     | no         |
# |  69 |   70 | admin     |          15 | male     | no         |
# |  70 |   71 | manage    |          17 | male     | no         |
# |  71 |   72 | admin     |          16 | female   | no         |
# |  72 |   73 | admin     |          12 | female   | no         |
# |  73 |   74 | admin     |          15 | female   | no         |
# |  74 |   75 | admin     |          15 | female   | no         |
# |  75 |   76 | admin     |          15 | female   | no         |
# |  76 |   77 | admin     |          12 | female   | no         |
# |  77 |   78 | admin     |          12 | female   | no         |
# |  78 |   79 | admin     |          16 | female   | no         |
# |  79 |   80 | admin     |          16 | female   | no         |
# |  80 |   81 | admin     |          12 | female   | no         |
# |  81 |   82 | admin     |          12 | female   | yes        |
# |  82 |   83 | admin     |          12 | female   | yes        |
# |  83 |   84 | admin     |           8 | female   | yes        |
# |  84 |   85 | admin     |          15 | male     | no         |
# |  85 |   86 | admin     |          15 | male     | no         |
# |  86 |   87 | admin     |          12 | male     | no         |
# |  87 |   88 | manage    |          19 | male     | no         |
# |  88 |   89 | manage    |          19 | male     | no         |
# |  89 |   90 | admin     |           8 | female   | no         |
# |  90 |   91 | admin     |          12 | female   | no         |
# |  91 |   92 | admin     |           8 | female   | no         |
# |  92 |   93 | admin     |          12 | female   | no         |
# |  93 |   94 | admin     |          12 | female   | no         |
# |  94 |   95 | admin     |          12 | female   | no         |
# |  95 |   96 | custodial |           8 | male     | yes        |
# |  96 |   97 | admin     |          17 | male     | yes        |
# |  97 |   98 | custodial |           8 | male     | yes        |
# |  98 |   99 | admin     |          12 | female   | yes        |
# |  99 |  100 | manage    |          18 | male     | no         |
# | 100 |  101 | manage    |          16 | male     | no         |
# | 101 |  102 | admin     |          14 | male     | no         |
# | 102 |  103 | manage    |          19 | male     | no         |
# | 103 |  104 | admin     |          15 | male     | no         |
# | 104 |  105 | admin     |          15 | male     | no         |
# | 105 |  106 | manage    |          19 | male     | no         |
# | 106 |  107 | admin     |          12 | female   | no         |
# | 107 |  108 | admin     |          12 | female   | no         |
# | 108 |  109 | admin     |          12 | male     | yes        |
# | 109 |  110 | admin     |          15 | male     | yes        |
# | 110 |  111 | custodial |          12 | male     | yes        |
# | 111 |  112 | custodial |          12 | male     | yes        |
# | 112 |  113 | manage    |          16 | male     | no         |
# | 113 |  114 | admin     |          14 | male     | no         |
# | 114 |  115 | admin     |          15 | male     | no         |
# | 115 |  116 | admin     |          15 | male     | no         |
# | 116 |  117 | admin     |          12 | female   | no         |
# | 117 |  118 | admin     |          12 | female   | no         |
# | 118 |  119 | admin     |          12 | female   | no         |
# | 119 |  120 | manage    |          16 | female   | no         |
# | 120 |  121 | admin     |          15 | female   | no         |
# | 121 |  122 | admin     |          15 | female   | no         |
# | 122 |  123 | admin     |          12 | female   | no         |
# | 123 |  124 | admin     |          16 | female   | no         |
# | 124 |  125 | admin     |          12 | male     | yes        |
# | 125 |  126 | custodial |          15 | male     | yes        |
# | 126 |  127 | custodial |          12 | male     | yes        |
# | 127 |  128 | admin     |          12 | female   | yes        |
# | 128 |  129 | manage    |          17 | male     | no         |
# | 129 |  130 | manage    |          20 | male     | no         |
# | 130 |  131 | admin     |          15 | male     | no         |
# | 131 |  132 | admin     |          12 | male     | no         |
# | 132 |  133 | admin     |          15 | male     | no         |
# | 133 |  134 | manage    |          16 | female   | no         |
# | 134 |  135 | admin     |          12 | female   | no         |
# | 135 |  136 | admin     |          12 | male     | no         |
# | 136 |  137 | manage    |          21 | male     | no         |
# | 137 |  138 | admin     |          12 | male     | no         |
# | 138 |  139 | admin     |           8 | female   | no         |
# | 139 |  140 | admin     |          12 | female   | no         |
# | 140 |  141 | admin     |          15 | female   | no         |
# | 141 |  142 | admin     |          12 | female   | no         |
# | 142 |  143 | admin     |          12 | female   | no         |
# | 143 |  144 | admin     |           8 | female   | no         |
# | 144 |  145 | admin     |          12 | male     | yes        |
# | 145 |  146 | admin     |          18 | male     | yes        |
# | 146 |  147 | admin     |          15 | male     | yes        |
# | 147 |  148 | admin     |          15 | female   | yes        |
# | 148 |  149 | admin     |          12 | male     | no         |
# | 149 |  150 | admin     |          12 | male     | no         |
# | 150 |  151 | manage    |          16 | male     | no         |
# | 151 |  152 | custodial |           8 | male     | no         |
# | 152 |  153 | admin     |          12 | female   | no         |
# | 153 |  154 | admin     |          12 | female   | no         |
# | 154 |  155 | admin     |          15 | male     | yes        |
# | 155 |  156 | admin     |          15 | male     | yes        |
# | 156 |  157 | admin     |          12 | female   | yes        |
# | 157 |  158 | admin     |          12 | female   | yes        |
# | 158 |  159 | admin     |          16 | female   | yes        |
# | 159 |  160 | manage    |          16 | male     | no         |
# | 160 |  161 | admin     |          16 | male     | no         |
# | 161 |  162 | manage    |          16 | male     | no         |
# | 162 |  163 | admin     |          15 | male     | no         |
# | 163 |  164 | admin     |          15 | female   | no         |
# | 164 |  165 | admin     |          15 | female   | no         |
# | 165 |  166 | admin     |          12 | female   | no         |
# | 166 |  167 | admin     |          12 | female   | no         |
# | 167 |  168 | manage    |          16 | female   | no         |
# | 168 |  169 | admin     |          12 | male     | yes        |
# | 169 |  170 | admin     |          12 | male     | yes        |
# | 170 |  171 | admin     |          12 | male     | yes        |
# | 171 |  172 | admin     |          15 | female   | yes        |
# | 172 |  173 | manage    |          20 | male     | no         |
# | 173 |  174 | custodial |           8 | male     | no         |
# | 174 |  175 | admin     |           8 | male     | no         |
# | 175 |  176 | admin     |          16 | female   | no         |
# | 176 |  177 | admin     |          12 | female   | no         |
# | 177 |  178 | admin     |          12 | female   | no         |
# | 178 |  179 | admin     |          12 | male     | yes        |
# | 179 |  180 | admin     |          12 | female   | yes        |
# | 180 |  181 | admin     |          12 | female   | yes        |
# | 181 |  182 | admin     |          12 | female   | yes        |
# | 182 |  183 | admin     |          15 | male     | no         |
# | 183 |  184 | admin     |          15 | male     | no         |
# | 184 |  185 | custodial |           8 | male     | no         |
# | 185 |  186 | admin     |          15 | male     | no         |
# | 186 |  187 | manage    |          16 | male     | no         |
# | 187 |  188 | admin     |          12 | female   | no         |
# | 188 |  189 | admin     |          12 | female   | no         |
# | 189 |  190 | admin     |           8 | female   | no         |
# | 190 |  191 | admin     |          12 | female   | no         |
# | 191 |  192 | admin     |          12 | male     | yes        |
# | 192 |  193 | admin     |          12 | female   | yes        |
# | 193 |  194 | admin     |          15 | female   | yes        |
# | 194 |  195 | admin     |          12 | female   | yes        |
# | 195 |  196 | admin     |          16 | female   | yes        |
# | 196 |  197 | manage    |          15 | male     | no         |
# | 197 |  198 | manage    |          19 | male     | no         |
# | 198 |  199 | manage    |          16 | male     | no         |
# | 199 |  200 | manage    |          17 | male     | no         |
# | 200 |  201 | admin     |          12 | male     | no         |
# | 201 |  202 | admin     |          15 | male     | no         |
# | 202 |  203 | admin     |          12 | male     | no         |
# | 203 |  204 | admin     |          15 | male     | no         |
# | 204 |  205 | manage    |          16 | male     | no         |
# | 205 |  206 | custodial |          12 | male     | no         |
# | 206 |  207 | admin     |          15 | male     | no         |
# | 207 |  208 | admin     |          12 | female   | no         |
# | 208 |  209 | admin     |           8 | female   | no         |
# | 209 |  210 | admin     |          15 | male     | yes        |
# | 210 |  211 | admin     |          15 | male     | yes        |
# | 211 |  212 | admin     |          15 | male     | yes        |
# | 212 |  213 | custodial |           8 | male     | yes        |
# | 213 |  214 | admin     |          12 | female   | yes        |
# | 214 |  215 | admin     |          12 | female   | yes        |
# | 215 |  216 | admin     |          15 | male     | no         |
# | 216 |  217 | admin     |          16 | male     | no         |
# | 217 |  218 | admin     |          15 | male     | no         |
# | 218 |  219 | admin     |          12 | male     | no         |
# | 219 |  220 | admin     |          12 | male     | no         |
# | 220 |  221 | admin     |          12 | female   | no         |
# | 221 |  222 | admin     |          15 | female   | no         |
# | 222 |  223 | admin     |           8 | female   | no         |
# | 223 |  224 | admin     |          12 | female   | no         |
# | 224 |  225 | admin     |          15 | female   | no         |
# | 225 |  226 | admin     |          16 | female   | no         |
# | 226 |  227 | admin     |          12 | female   | no         |
# | 227 |  228 | admin     |          15 | female   | no         |
# | 228 |  229 | admin     |          12 | female   | no         |
# | 229 |  230 | admin     |          15 | male     | yes        |
# | 230 |  231 | manage    |          16 | male     | no         |
# | 231 |  232 | manage    |          19 | male     | no         |
# | 232 |  233 | admin     |          15 | male     | no         |
# | 233 |  234 | admin     |          15 | male     | no         |
# | 234 |  235 | manage    |          19 | male     | no         |
# | 235 |  236 | admin     |           8 | female   | no         |
# | 236 |  237 | admin     |          12 | female   | no         |
# | 237 |  238 | admin     |          12 | female   | no         |
# | 238 |  239 | admin     |          12 | female   | no         |
# | 239 |  240 | manage    |          16 | female   | no         |
# | 240 |  241 | admin     |           8 | female   | no         |
# | 241 |  242 | admin     |          12 | female   | no         |
# | 242 |  243 | admin     |          12 | female   | no         |
# | 243 |  244 | admin     |           8 | female   | no         |
# | 244 |  245 | admin     |          12 | female   | no         |
# | 245 |  246 | admin     |          12 | female   | no         |
# | 246 |  247 | admin     |          12 | female   | no         |
# | 247 |  248 | admin     |          12 | female   | no         |
# | 248 |  249 | admin     |          12 | female   | no         |
# | 249 |  250 | admin     |          15 | female   | no         |
# | 250 |  251 | admin     |          12 | female   | no         |
# | 251 |  252 | admin     |          12 | male     | yes        |
# | 252 |  253 | admin     |           8 | female   | yes        |
# | 253 |  254 | manage    |          18 | male     | no         |
# | 254 |  255 | custodial |          12 | male     | no         |
# | 255 |  256 | manage    |          19 | male     | no         |
# | 256 |  257 | manage    |          19 | male     | no         |
# | 257 |  258 | admin     |           8 | male     | no         |
# | 258 |  259 | admin     |          12 | female   | no         |
# | 259 |  260 | admin     |          12 | female   | no         |
# | 260 |  261 | admin     |          12 | female   | no         |
# | 261 |  262 | admin     |          12 | female   | no         |
# | 262 |  263 | admin     |          12 | female   | no         |
# | 263 |  264 | admin     |          12 | female   | no         |
# | 264 |  265 | admin     |          12 | female   | no         |
# | 265 |  266 | admin     |          16 | female   | no         |
# | 266 |  267 | admin     |          12 | female   | no         |
# | 267 |  268 | admin     |          12 | male     | yes        |
# | 268 |  269 | admin     |          15 | male     | no         |
# | 269 |  270 | admin     |          15 | male     | no         |
# | 270 |  271 | admin     |          15 | male     | no         |
# | 271 |  272 | admin     |          18 | male     | no         |
# | 272 |  273 | custodial |          12 | male     | no         |
# | 273 |  274 | manage    |          16 | male     | no         |
# | 274 |  275 | admin     |          12 | male     | no         |
# | 275 |  276 | manage    |          16 | male     | no         |
# | 276 |  277 | manage    |          16 | female   | no         |
# | 277 |  278 | admin     |           8 | female   | no         |
# | 278 |  279 | admin     |          12 | female   | no         |
# | 279 |  280 | admin     |          12 | female   | no         |
# | 280 |  281 | custodial |           8 | male     | yes        |
# | 281 |  282 | admin     |          14 | male     | yes        |
# | 282 |  283 | manage    |          19 | male     | no         |
# | 283 |  284 | manage    |          19 | male     | no         |
# | 284 |  285 | custodial |           8 | male     | no         |
# | 285 |  286 | manage    |          15 | male     | no         |
# | 286 |  287 | admin     |          16 | male     | no         |
# | 287 |  288 | manage    |          15 | male     | no         |
# | 288 |  289 | manage    |          17 | male     | no         |
# | 289 |  290 | manage    |          18 | male     | no         |
# | 290 |  291 | custodial |          12 | male     | no         |
# | 291 |  292 | admin     |          14 | male     | no         |
# | 292 |  293 | admin     |          15 | male     | no         |
# | 293 |  294 | admin     |          12 | male     | no         |
# | 294 |  295 | admin     |           8 | male     | no         |
# | 295 |  296 | admin     |          12 | male     | no         |
# | 296 |  297 | admin     |          12 | female   | no         |
# | 297 |  298 | admin     |          12 | female   | no         |
# | 298 |  299 | admin     |          15 | female   | no         |
# | 299 |  300 | admin     |          16 | male     | yes        |
# | 300 |  301 | admin     |          12 | male     | yes        |
# | 301 |  302 | admin     |           8 | male     | yes        |
# | 302 |  303 | custodial |          12 | male     | yes        |
# | 303 |  304 | admin     |          15 | female   | yes        |
# | 304 |  305 | custodial |          12 | male     | no         |
# | 305 |  306 | admin     |          15 | male     | no         |
# | 306 |  307 | manage    |          16 | male     | no         |
# | 307 |  308 | admin     |          15 | male     | no         |
# | 308 |  309 | admin     |          15 | male     | no         |
# | 309 |  310 | admin     |          16 | male     | no         |
# | 310 |  311 | admin     |          12 | female   | no         |
# | 311 |  312 | admin     |          12 | female   | no         |
# | 312 |  313 | admin     |          12 | female   | no         |
# | 313 |  314 | admin     |          12 | female   | no         |
# | 314 |  315 | admin     |          12 | female   | no         |
# | 315 |  316 | admin     |          15 | male     | yes        |
# | 316 |  317 | admin     |          12 | male     | yes        |
# | 317 |  318 | manage    |          16 | male     | no         |
# | 318 |  319 | admin     |          15 | male     | no         |
# | 319 |  320 | admin     |          12 | male     | no         |
# | 320 |  321 | admin     |          12 | female   | no         |
# | 321 |  322 | admin     |          12 | female   | no         |
# | 322 |  323 | admin     |          15 | female   | no         |
# | 323 |  324 | admin     |          12 | female   | no         |
# | 324 |  325 | admin     |           8 | female   | no         |
# | 325 |  326 | custodial |           8 | male     | yes        |
# | 326 |  327 | admin     |          12 | male     | yes        |
# | 327 |  328 | manage    |          18 | male     | no         |
# | 328 |  329 | manage    |          18 | male     | no         |
# | 329 |  330 | admin     |          15 | male     | no         |
# | 330 |  331 | admin     |          12 | female   | no         |
# | 331 |  332 | admin     |          16 | female   | no         |
# | 332 |  333 | admin     |          15 | female   | no         |
# | 333 |  334 | admin     |          12 | female   | yes        |
# | 334 |  335 | custodial |           8 | male     | no         |
# | 335 |  336 | manage    |          16 | male     | no         |
# | 336 |  337 | admin     |          12 | female   | no         |
# | 337 |  338 | admin     |           8 | female   | no         |
# | 338 |  339 | admin     |           8 | female   | no         |
# | 339 |  340 | admin     |           8 | female   | no         |
# | 340 |  341 | manage    |          12 | male     | yes        |
# | 341 |  342 | admin     |          12 | female   | yes        |
# | 342 |  343 | manage    |          16 | male     | no         |
# | 343 |  344 | admin     |          12 | male     | no         |
# | 344 |  345 | admin     |          12 | female   | no         |
# | 345 |  346 | admin     |          15 | female   | no         |
# | 346 |  347 | admin     |          12 | female   | no         |
# | 347 |  348 | manage    |          16 | female   | no         |
# | 348 |  349 | admin     |          17 | female   | no         |
# | 349 |  350 | admin     |          12 | female   | no         |
# | 350 |  351 | admin     |          12 | female   | no         |
# | 351 |  352 | admin     |           8 | female   | no         |
# | 352 |  353 | custodial |          12 | male     | yes        |
# | 353 |  354 | admin     |          12 | female   | yes        |
# | 354 |  355 | admin     |          15 | male     | no         |
# | 355 |  356 | admin     |          15 | male     | no         |
# | 356 |  357 | admin     |           8 | female   | no         |
# | 357 |  358 | admin     |          15 | female   | no         |
# | 358 |  359 | admin     |          12 | female   | no         |
# | 359 |  360 | admin     |          12 | female   | no         |
# | 360 |  361 | admin     |          12 | female   | no         |
# | 361 |  362 | admin     |           8 | female   | no         |
# | 362 |  363 | admin     |          16 | male     | yes        |
# | 363 |  364 | admin     |          12 | female   | yes        |
# | 364 |  365 | admin     |           8 | female   | yes        |
# | 365 |  366 | admin     |          12 | female   | yes        |
# | 366 |  367 | admin     |          12 | female   | yes        |
# | 367 |  368 | admin     |          12 | female   | yes        |
# | 368 |  369 | admin     |          14 | male     | no         |
# | 369 |  370 | admin     |          16 | female   | no         |
# | 370 |  371 | manage    |          16 | female   | no         |
# | 371 |  372 | admin     |          15 | male     | no         |
# | 372 |  373 | admin     |          12 | male     | no         |
# | 373 |  374 | admin     |          15 | male     | no         |
# | 374 |  375 | admin     |          12 | male     | no         |
# | 375 |  376 | admin     |          15 | male     | no         |
# | 376 |  377 | admin     |          15 | male     | no         |
# | 377 |  378 | admin     |           8 | female   | no         |
# | 378 |  379 | admin     |           8 | female   | no         |
# | 379 |  380 | admin     |          12 | female   | no         |
# | 380 |  381 | admin     |          17 | male     | yes        |
# | 381 |  382 | admin     |          12 | male     | yes        |
# | 382 |  383 | manage    |          17 | male     | yes        |
# | 383 |  384 | admin     |          12 | female   | yes        |
# | 384 |  385 | custodial |          12 | male     | no         |
# | 385 |  386 | custodial |           8 | male     | no         |
# | 386 |  387 | manage    |          19 | male     | no         |
# | 387 |  388 | admin     |          14 | male     | no         |
# | 388 |  389 | manage    |          19 | male     | no         |
# | 389 |  390 | admin     |          15 | female   | no         |
# | 390 |  391 | admin     |          12 | female   | no         |
# | 391 |  392 | admin     |          12 | female   | no         |
# | 392 |  393 | admin     |          12 | female   | no         |
# | 393 |  394 | admin     |           8 | female   | no         |
# | 394 |  395 | admin     |          12 | female   | no         |
# | 395 |  396 | admin     |          12 | female   | no         |
# | 396 |  397 | admin     |          12 | female   | no         |
# | 397 |  398 | admin     |          12 | female   | no         |
# | 398 |  399 | admin     |          12 | female   | no         |
# | 399 |  400 | admin     |          12 | female   | no         |
# | 400 |  401 | admin     |          12 | female   | no         |
# | 401 |  402 | admin     |          12 | female   | no         |
# | 402 |  403 | admin     |          12 | female   | yes        |
# | 403 |  404 | admin     |          12 | female   | yes        |
# | 404 |  405 | admin     |          12 | female   | yes        |
# | 405 |  406 | manage    |          17 | male     | no         |
# | 406 |  407 | admin     |          15 | male     | no         |
# | 407 |  408 | manage    |          19 | male     | no         |
# | 408 |  409 | admin     |          19 | male     | no         |
# | 409 |  410 | admin     |           8 | female   | no         |
# | 410 |  411 | admin     |          12 | female   | no         |
# | 411 |  412 | admin     |          12 | female   | no         |
# | 412 |  413 | manage    |          16 | female   | no         |
# | 413 |  414 | custodial |           8 | male     | yes        |
# | 414 |  415 | admin     |          15 | male     | yes        |
# | 415 |  416 | admin     |          15 | male     | no         |
# | 416 |  417 | admin     |          15 | male     | no         |
# | 417 |  418 | admin     |          15 | male     | no         |
# | 418 |  419 | admin     |          15 | male     | no         |
# | 419 |  420 | manage    |          19 | male     | no         |
# | 420 |  421 | admin     |          15 | male     | no         |
# | 421 |  422 | admin     |          15 | male     | no         |
# | 422 |  423 | admin     |          12 | female   | no         |
# | 423 |  424 | admin     |          15 | female   | no         |
# | 424 |  425 | admin     |          12 | female   | no         |
# | 425 |  426 | admin     |          16 | male     | yes        |
# | 426 |  427 | admin     |           8 | male     | yes        |
# | 427 |  428 | admin     |          15 | male     | yes        |
# | 428 |  429 | custodial |           8 | male     | yes        |
# | 429 |  430 | manage    |          19 | male     | yes        |
# | 430 |  431 | manage    |          18 | male     | no         |
# | 431 |  432 | admin     |          12 | male     | no         |
# | 432 |  433 | admin     |          12 | male     | no         |
# | 433 |  434 | admin     |          16 | male     | no         |
# | 434 |  435 | admin     |          15 | male     | no         |
# | 435 |  436 | admin     |          12 | male     | no         |
# | 436 |  437 | admin     |           8 | male     | no         |
# | 437 |  438 | admin     |          15 | male     | no         |
# | 438 |  439 | admin     |          12 | female   | no         |
# | 439 |  440 | admin     |           8 | female   | no         |
# | 440 |  441 | admin     |          15 | female   | no         |
# | 441 |  442 | admin     |          12 | female   | no         |
# | 442 |  443 | admin     |           8 | female   | no         |
# | 443 |  444 | admin     |          12 | female   | no         |
# | 444 |  445 | admin     |          15 | male     | yes        |
# | 445 |  446 | manage    |          16 | male     | yes        |
# | 446 |  447 | admin     |          15 | male     | yes        |
# | 447 |  448 | admin     |          12 | female   | yes        |
# | 448 |  449 | manage    |          16 | male     | no         |
# | 449 |  450 | manage    |          19 | male     | no         |
# | 450 |  451 | admin     |          15 | male     | no         |
# | 451 |  452 | admin     |          12 | male     | no         |
# | 452 |  453 | admin     |          15 | male     | no         |
# | 453 |  454 | manage    |          19 | male     | no         |
# | 454 |  455 | manage    |          16 | male     | no         |
# | 455 |  456 | manage    |          19 | male     | no         |
# | 456 |  457 | admin     |          15 | male     | no         |
# | 457 |  458 | manage    |          19 | male     | no         |
# | 458 |  459 | admin     |          12 | female   | no         |
# | 459 |  460 | admin     |          12 | female   | no         |
# | 460 |  461 | admin     |           8 | female   | no         |
# | 461 |  462 | manage    |          16 | female   | no         |
# | 462 |  463 | admin     |          15 | female   | no         |
# | 463 |  464 | manage    |          19 | male     | no         |
# | 464 |  465 | admin     |          12 | male     | no         |
# | 465 |  466 | admin     |          12 | female   | no         |
# | 466 |  467 | admin     |          16 | female   | no         |
# | 467 |  468 | manage    |          16 | female   | no         |
# | 468 |  469 | admin     |          15 | female   | no         |
# | 469 |  470 | admin     |          12 | male     | yes        |
# | 470 |  471 | admin     |          15 | male     | yes        |
# | 471 |  472 | admin     |          15 | male     | no         |
# | 472 |  473 | admin     |          12 | female   | no         |
# | 473 |  474 | admin     |          12 | female   | no         |

# %% [markdown]
# ### sorting the data set according to education level in ascending order, similar to sql 'order by clause'

# %%
sorted_data = data.sort_values(['education'])

# %% [markdown]
# **you can see here, that records are sorted according to education level.**
# * but, if you want to sort in accordance with multiple columns . you can also do this.
# * for an example, see the below table, here if we analyze education level '8' and check thier respective ID's
# * we notice that order ID's are not sorted.
#
# **to do the sorting read below.**

# %%
print(sorted_data.to_markdown())
# Out:
# |     |   id | job       |   education | gender   | minority   |
# |----:|-----:|:----------|------------:|:---------|:-----------|
# |  35 |   36 | admin     |           8 | female   | no         |
# | 151 |  152 | custodial |           8 | male     | no         |
# | 222 |  223 | admin     |           8 | female   | no         |
# | 325 |  326 | custodial |           8 | male     | yes        |
# |  83 |   84 | admin     |           8 | female   | yes        |
# | 393 |  394 | admin     |           8 | female   | no         |
# | 235 |  236 | admin     |           8 | female   | no         |
# |  43 |   44 | admin     |           8 | male     | no         |
# | 385 |  386 | custodial |           8 | male     | no         |
# | 143 |  144 | admin     |           8 | female   | no         |
# | 334 |  335 | custodial |           8 | male     | no         |
# | 240 |  241 | admin     |           8 | female   | no         |
# | 378 |  379 | admin     |           8 | female   | no         |
# | 324 |  325 | admin     |           8 | female   | no         |
# | 377 |  378 | admin     |           8 | female   | no         |
# | 138 |  139 | admin     |           8 | female   | no         |
# | 243 |  244 | admin     |           8 | female   | no         |
# | 337 |  338 | admin     |           8 | female   | no         |
# | 338 |  339 | admin     |           8 | female   | no         |
# | 364 |  365 | admin     |           8 | female   | yes        |
# | 339 |  340 | admin     |           8 | female   | no         |
# | 361 |  362 | admin     |           8 | female   | no         |
# |  60 |   61 | admin     |           8 | male     | yes        |
# |  64 |   65 | admin     |           8 | male     | no         |
# | 356 |  357 | admin     |           8 | female   | no         |
# | 252 |  253 | admin     |           8 | female   | yes        |
# | 351 |  352 | admin     |           8 | female   | no         |
# | 301 |  302 | admin     |           8 | male     | yes        |
# |  89 |   90 | admin     |           8 | female   | no         |
# | 257 |  258 | admin     |           8 | male     | no         |
# | 212 |  213 | custodial |           8 | male     | yes        |
# | 174 |  175 | admin     |           8 | male     | no         |
# | 173 |  174 | custodial |           8 | male     | no         |
# |   3 |    4 | admin     |           8 | female   | no         |
# | 460 |  461 | admin     |           8 | female   | no         |
# | 184 |  185 | custodial |           8 | male     | no         |
# | 294 |  295 | admin     |           8 | male     | no         |
# | 189 |  190 | admin     |           8 | female   | no         |
# |  11 |   12 | admin     |           8 | male     | yes        |
# | 442 |  443 | admin     |           8 | female   | no         |
# | 439 |  440 | admin     |           8 | female   | no         |
# | 277 |  278 | admin     |           8 | female   | no         |
# | 436 |  437 | admin     |           8 | male     | no         |
# | 284 |  285 | custodial |           8 | male     | no         |
# |  95 |   96 | custodial |           8 | male     | yes        |
# |  97 |   98 | custodial |           8 | male     | yes        |
# | 428 |  429 | custodial |           8 | male     | yes        |
# | 426 |  427 | admin     |           8 | male     | yes        |
# | 409 |  410 | admin     |           8 | female   | no         |
# | 413 |  414 | custodial |           8 | male     | yes        |
# |  91 |   92 | admin     |           8 | female   | no         |
# | 280 |  281 | custodial |           8 | male     | yes        |
# | 208 |  209 | admin     |           8 | female   | no         |
# | 264 |  265 | admin     |          12 | female   | no         |
# | 274 |  275 | admin     |          12 | male     | no         |
# | 272 |  273 | custodial |          12 | male     | no         |
# | 259 |  260 | admin     |          12 | female   | no         |
# | 296 |  297 | admin     |          12 | female   | no         |
# | 260 |  261 | admin     |          12 | female   | no         |
# | 261 |  262 | admin     |          12 | female   | no         |
# | 262 |  263 | admin     |          12 | female   | no         |
# | 258 |  259 | admin     |          12 | female   | no         |
# | 293 |  294 | admin     |          12 | male     | no         |
# | 267 |  268 | admin     |          12 | male     | yes        |
# | 278 |  279 | admin     |          12 | female   | no         |
# | 290 |  291 | custodial |          12 | male     | no         |
# | 279 |  280 | admin     |          12 | female   | no         |
# | 263 |  264 | admin     |          12 | female   | no         |
# | 266 |  267 | admin     |          12 | female   | no         |
# | 295 |  296 | admin     |          12 | male     | no         |
# | 236 |  237 | admin     |          12 | female   | no         |
# | 242 |  243 | admin     |          12 | female   | no         |
# | 251 |  252 | admin     |          12 | male     | yes        |
# | 180 |  181 | admin     |          12 | female   | yes        |
# | 181 |  182 | admin     |          12 | female   | yes        |
# | 187 |  188 | admin     |          12 | female   | no         |
# | 188 |  189 | admin     |          12 | female   | no         |
# | 190 |  191 | admin     |          12 | female   | no         |
# | 191 |  192 | admin     |          12 | male     | yes        |
# | 192 |  193 | admin     |          12 | female   | yes        |
# | 194 |  195 | admin     |          12 | female   | yes        |
# | 200 |  201 | admin     |          12 | male     | no         |
# | 202 |  203 | admin     |          12 | male     | no         |
# | 205 |  206 | custodial |          12 | male     | no         |
# | 207 |  208 | admin     |          12 | female   | no         |
# | 213 |  214 | admin     |          12 | female   | yes        |
# | 214 |  215 | admin     |          12 | female   | yes        |
# | 254 |  255 | custodial |          12 | male     | no         |
# | 218 |  219 | admin     |          12 | male     | no         |
# | 220 |  221 | admin     |          12 | female   | no         |
# | 223 |  224 | admin     |          12 | female   | no         |
# | 226 |  227 | admin     |          12 | female   | no         |
# | 228 |  229 | admin     |          12 | female   | no         |
# | 472 |  473 | admin     |          12 | female   | no         |
# | 237 |  238 | admin     |          12 | female   | no         |
# | 238 |  239 | admin     |          12 | female   | no         |
# | 241 |  242 | admin     |          12 | female   | no         |
# | 244 |  245 | admin     |          12 | female   | no         |
# | 245 |  246 | admin     |          12 | female   | no         |
# | 246 |  247 | admin     |          12 | female   | no         |
# | 247 |  248 | admin     |          12 | female   | no         |
# | 248 |  249 | admin     |          12 | female   | no         |
# | 250 |  251 | admin     |          12 | female   | no         |
# | 219 |  220 | admin     |          12 | male     | no         |
# | 297 |  298 | admin     |          12 | female   | no         |
# | 321 |  322 | admin     |          12 | female   | no         |
# | 302 |  303 | custodial |          12 | male     | yes        |
# | 403 |  404 | admin     |          12 | female   | yes        |
# | 402 |  403 | admin     |          12 | female   | yes        |
# | 401 |  402 | admin     |          12 | female   | no         |
# | 400 |  401 | admin     |          12 | female   | no         |
# | 399 |  400 | admin     |          12 | female   | no         |
# | 398 |  399 | admin     |          12 | female   | no         |
# | 404 |  405 | admin     |          12 | female   | yes        |
# | 397 |  398 | admin     |          12 | female   | no         |
# | 395 |  396 | admin     |          12 | female   | no         |
# | 394 |  395 | admin     |          12 | female   | no         |
# | 392 |  393 | admin     |          12 | female   | no         |
# | 391 |  392 | admin     |          12 | female   | no         |
# | 390 |  391 | admin     |          12 | female   | no         |
# | 384 |  385 | custodial |          12 | male     | no         |
# | 396 |  397 | admin     |          12 | female   | no         |
# | 383 |  384 | admin     |          12 | female   | yes        |
# | 410 |  411 | admin     |          12 | female   | no         |
# | 422 |  423 | admin     |          12 | female   | no         |
# | 469 |  470 | admin     |          12 | male     | yes        |
# | 465 |  466 | admin     |          12 | female   | no         |
# | 464 |  465 | admin     |          12 | male     | no         |
# | 459 |  460 | admin     |          12 | female   | no         |
# | 458 |  459 | admin     |          12 | female   | no         |
# | 451 |  452 | admin     |          12 | male     | no         |
# | 411 |  412 | admin     |          12 | female   | no         |
# | 447 |  448 | admin     |          12 | female   | yes        |
# | 441 |  442 | admin     |          12 | female   | no         |
# | 438 |  439 | admin     |          12 | female   | no         |
# | 435 |  436 | admin     |          12 | male     | no         |
# | 432 |  433 | admin     |          12 | male     | no         |
# | 431 |  432 | admin     |          12 | male     | no         |
# | 424 |  425 | admin     |          12 | female   | no         |
# | 443 |  444 | admin     |          12 | female   | no         |
# | 300 |  301 | admin     |          12 | male     | yes        |
# | 381 |  382 | admin     |          12 | male     | yes        |
# | 374 |  375 | admin     |          12 | male     | no         |
# | 333 |  334 | admin     |          12 | female   | yes        |
# | 330 |  331 | admin     |          12 | female   | no         |
# | 326 |  327 | admin     |          12 | male     | yes        |
# | 323 |  324 | admin     |          12 | female   | no         |
# | 179 |  180 | admin     |          12 | female   | yes        |
# | 320 |  321 | admin     |          12 | female   | no         |
# | 336 |  337 | admin     |          12 | female   | no         |
# | 319 |  320 | admin     |          12 | male     | no         |
# | 314 |  315 | admin     |          12 | female   | no         |
# | 313 |  314 | admin     |          12 | female   | no         |
# | 312 |  313 | admin     |          12 | female   | no         |
# | 311 |  312 | admin     |          12 | female   | no         |
# | 310 |  311 | admin     |          12 | female   | no         |
# | 304 |  305 | custodial |          12 | male     | no         |
# | 316 |  317 | admin     |          12 | male     | yes        |
# | 379 |  380 | admin     |          12 | female   | no         |
# | 340 |  341 | manage    |          12 | male     | yes        |
# | 343 |  344 | admin     |          12 | male     | no         |
# | 372 |  373 | admin     |          12 | male     | no         |
# | 367 |  368 | admin     |          12 | female   | yes        |
# | 366 |  367 | admin     |          12 | female   | yes        |
# | 365 |  366 | admin     |          12 | female   | yes        |
# | 363 |  364 | admin     |          12 | female   | yes        |
# | 360 |  361 | admin     |          12 | female   | no         |
# | 341 |  342 | admin     |          12 | female   | yes        |
# | 359 |  360 | admin     |          12 | female   | no         |
# | 353 |  354 | admin     |          12 | female   | yes        |
# | 352 |  353 | custodial |          12 | male     | yes        |
# | 350 |  351 | admin     |          12 | female   | no         |
# | 349 |  350 | admin     |          12 | female   | no         |
# | 346 |  347 | admin     |          12 | female   | no         |
# | 344 |  345 | admin     |          12 | female   | no         |
# | 358 |  359 | admin     |          12 | female   | no         |
# | 178 |  179 | admin     |          12 | male     | yes        |
# | 473 |  474 | admin     |          12 | female   | no         |
# | 176 |  177 | admin     |          12 | female   | no         |
# | 124 |  125 | admin     |          12 | male     | yes        |
# | 126 |  127 | custodial |          12 | male     | yes        |
# | 127 |  128 | admin     |          12 | female   | yes        |
# |  50 |   51 | admin     |          12 | male     | no         |
# |  47 |   48 | custodial |          12 | male     | no         |
# |  46 |   47 | admin     |          12 | female   | no         |
# | 131 |  132 | admin     |          12 | male     | no         |
# |  44 |   45 | custodial |          12 | male     | no         |
# |  42 |   43 | admin     |          12 | male     | no         |
# | 134 |  135 | admin     |          12 | female   | no         |
# |  94 |   95 | admin     |          12 | female   | no         |
# | 137 |  138 | admin     |          12 | male     | no         |
# | 139 |  140 | admin     |          12 | female   | no         |
# |  40 |   41 | admin     |          12 | female   | yes        |
# | 141 |  142 | admin     |          12 | female   | no         |
# | 142 |  143 | admin     |          12 | female   | no         |
# | 144 |  145 | admin     |          12 | male     | yes        |
# |  36 |   37 | admin     |          12 | male     | yes        |
# |  30 |   31 | admin     |          12 | male     | no         |
# | 122 |  123 | admin     |          12 | female   | no         |
# | 148 |  149 | admin     |          12 | male     | no         |
# |  53 |   54 | admin     |          12 | male     | no         |
# |  54 |   55 | admin     |          12 | male     | no         |
# |  93 |   94 | admin     |          12 | female   | no         |
# |  92 |   93 | admin     |          12 | female   | no         |
# |  90 |   91 | admin     |          12 | female   | no         |
# |  86 |   87 | admin     |          12 | male     | no         |
# | 177 |  178 | admin     |          12 | female   | no         |
# |  82 |   83 | admin     |          12 | female   | yes        |
# |  81 |   82 | admin     |          12 | female   | yes        |
# | 106 |  107 | admin     |          12 | female   | no         |
# | 107 |  108 | admin     |          12 | female   | no         |
# | 108 |  109 | admin     |          12 | male     | yes        |
# |  80 |   81 | admin     |          12 | female   | no         |
# |  77 |   78 | admin     |          12 | female   | no         |
# | 110 |  111 | custodial |          12 | male     | yes        |
# |  76 |   77 | admin     |          12 | female   | no         |
# |  72 |   73 | admin     |          12 | female   | no         |
# | 111 |  112 | custodial |          12 | male     | yes        |
# |  59 |   60 | admin     |          12 | male     | yes        |
# | 116 |  117 | admin     |          12 | female   | no         |
# | 117 |  118 | admin     |          12 | female   | no         |
# | 118 |  119 | admin     |          12 | female   | no         |
# | 149 |  150 | admin     |          12 | male     | no         |
# | 135 |  136 | admin     |          12 | male     | no         |
# |  98 |   99 | admin     |          12 | female   | yes        |
# | 157 |  158 | admin     |          12 | female   | yes        |
# |  18 |   19 | admin     |          12 | male     | no         |
# | 156 |  157 | admin     |          12 | female   | yes        |
# |  15 |   16 | admin     |          12 | male     | no         |
# |  23 |   24 | admin     |          12 | female   | yes        |
# |  14 |   15 | admin     |          12 | male     | no         |
# |   9 |   10 | admin     |          12 | female   | no         |
# |  21 |   22 | admin     |          12 | male     | yes        |
# |   7 |    8 | admin     |          12 | female   | no         |
# | 153 |  154 | admin     |          12 | female   | no         |
# | 165 |  166 | admin     |          12 | female   | no         |
# | 166 |  167 | admin     |          12 | female   | no         |
# | 168 |  169 | admin     |          12 | male     | yes        |
# | 169 |  170 | admin     |          12 | male     | yes        |
# | 170 |  171 | admin     |          12 | male     | yes        |
# |   2 |    3 | admin     |          12 | female   | no         |
# | 152 |  153 | admin     |          12 | female   | no         |
# |  19 |   20 | admin     |          12 | female   | no         |
# | 281 |  282 | admin     |          14 | male     | yes        |
# | 113 |  114 | admin     |          14 | male     | no         |
# | 291 |  292 | admin     |          14 | male     | no         |
# | 387 |  388 | admin     |          14 | male     | no         |
# | 101 |  102 | admin     |          14 | male     | no         |
# | 368 |  369 | admin     |          14 | male     | no         |
# | 389 |  390 | admin     |          15 | female   | no         |
# | 345 |  346 | admin     |          15 | female   | no         |
# | 452 |  453 | admin     |          15 | male     | no         |
# | 456 |  457 | admin     |          15 | male     | no         |
# |  73 |   74 | admin     |          15 | female   | no         |
# |  74 |   75 | admin     |          15 | female   | no         |
# |  75 |   76 | admin     |          15 | female   | no         |
# |  32 |   33 | admin     |          15 | male     | no         |
# |  29 |   30 | admin     |          15 | male     | no         |
# | 406 |  407 | admin     |          15 | male     | no         |
# |  27 |   28 | admin     |          15 | male     | no         |
# |   6 |    7 | admin     |          15 | male     | no         |
# |  25 |   26 | admin     |          15 | male     | no         |
# |  24 |   25 | admin     |          15 | female   | yes        |
# |  69 |   70 | admin     |          15 | male     | no         |
# |   5 |    6 | admin     |          15 | male     | no         |
# | 332 |  333 | admin     |          15 | female   | no         |
# | 414 |  415 | admin     |          15 | male     | yes        |
# | 329 |  330 | admin     |          15 | male     | no         |
# |  84 |   85 | admin     |          15 | male     | no         |
# |   4 |    5 | admin     |          15 | male     | no         |
# | 418 |  419 | admin     |          15 | male     | no         |
# | 415 |  416 | admin     |          15 | male     | no         |
# | 322 |  323 | admin     |          15 | female   | no         |
# | 468 |  469 | admin     |          15 | female   | no         |
# | 470 |  471 | admin     |          15 | male     | yes        |
# | 318 |  319 | admin     |          15 | male     | no         |
# | 471 |  472 | admin     |          15 | male     | no         |
# | 315 |  316 | admin     |          15 | male     | yes        |
# | 462 |  463 | admin     |          15 | female   | no         |
# |  37 |   38 | admin     |          15 | male     | yes        |
# | 354 |  355 | admin     |          15 | male     | no         |
# | 420 |  421 | admin     |          15 | male     | no         |
# |  41 |   42 | admin     |          15 | male     | no         |
# |  22 |   23 | admin     |          15 | female   | yes        |
# |  45 |   46 | admin     |          15 | female   | no         |
# | 434 |  435 | admin     |          15 | male     | no         |
# |  16 |   17 | admin     |          15 | male     | no         |
# |  48 |   49 | admin     |          15 | male     | no         |
# | 437 |  438 | admin     |          15 | male     | no         |
# | 423 |  424 | admin     |          15 | female   | no         |
# |  39 |   40 | admin     |          15 | female   | yes        |
# |  51 |   52 | admin     |          15 | male     | no         |
# | 440 |  441 | admin     |          15 | female   | no         |
# | 376 |  377 | admin     |          15 | male     | no         |
# |  13 |   14 | admin     |          15 | female   | yes        |
# | 375 |  376 | admin     |          15 | male     | no         |
# | 373 |  374 | admin     |          15 | male     | no         |
# |  12 |   13 | admin     |          15 | male     | yes        |
# | 371 |  372 | admin     |          15 | male     | no         |
# | 444 |  445 | admin     |          15 | male     | yes        |
# | 417 |  418 | admin     |          15 | male     | no         |
# | 446 |  447 | admin     |          15 | male     | yes        |
# |  55 |   56 | admin     |          15 | male     | no         |
# |  56 |   57 | admin     |          15 | male     | no         |
# | 421 |  422 | admin     |          15 | male     | no         |
# |  57 |   58 | admin     |          15 | female   | no         |
# | 450 |  451 | admin     |          15 | male     | no         |
# |  58 |   59 | admin     |          15 | male     | yes        |
# |   8 |    9 | admin     |          15 | female   | no         |
# | 357 |  358 | admin     |          15 | female   | no         |
# | 355 |  356 | admin     |          15 | male     | no         |
# | 427 |  428 | admin     |          15 | male     | yes        |
# | 416 |  417 | admin     |          15 | male     | no         |
# |  85 |   86 | admin     |          15 | male     | no         |
# | 140 |  141 | admin     |          15 | female   | no         |
# | 224 |  225 | admin     |          15 | female   | no         |
# | 227 |  228 | admin     |          15 | female   | no         |
# | 147 |  148 | admin     |          15 | female   | yes        |
# | 229 |  230 | admin     |          15 | male     | yes        |
# | 232 |  233 | admin     |          15 | male     | no         |
# | 233 |  234 | admin     |          15 | male     | no         |
# | 146 |  147 | admin     |          15 | male     | yes        |
# | 221 |  222 | admin     |          15 | female   | no         |
# | 132 |  133 | admin     |          15 | male     | no         |
# | 130 |  131 | admin     |          15 | male     | no         |
# | 125 |  126 | custodial |          15 | male     | yes        |
# | 121 |  122 | admin     |          15 | female   | no         |
# | 120 |  121 | admin     |          15 | female   | no         |
# | 268 |  269 | admin     |          15 | male     | no         |
# | 269 |  270 | admin     |          15 | male     | no         |
# | 270 |  271 | admin     |          15 | male     | no         |
# | 249 |  250 | admin     |          15 | female   | no         |
# | 115 |  116 | admin     |          15 | male     | no         |
# | 154 |  155 | admin     |          15 | male     | yes        |
# | 215 |  216 | admin     |          15 | male     | no         |
# | 171 |  172 | admin     |          15 | female   | yes        |
# | 182 |  183 | admin     |          15 | male     | no         |
# | 183 |  184 | admin     |          15 | male     | no         |
# | 185 |  186 | admin     |          15 | male     | no         |
# | 164 |  165 | admin     |          15 | female   | no         |
# | 193 |  194 | admin     |          15 | female   | yes        |
# | 163 |  164 | admin     |          15 | female   | no         |
# | 217 |  218 | admin     |          15 | male     | no         |
# | 196 |  197 | manage    |          15 | male     | no         |
# | 201 |  202 | admin     |          15 | male     | no         |
# | 203 |  204 | admin     |          15 | male     | no         |
# | 206 |  207 | admin     |          15 | male     | no         |
# | 209 |  210 | admin     |          15 | male     | yes        |
# | 210 |  211 | admin     |          15 | male     | yes        |
# | 211 |  212 | admin     |          15 | male     | yes        |
# | 155 |  156 | admin     |          15 | male     | yes        |
# | 162 |  163 | admin     |          15 | male     | no         |
# | 114 |  115 | admin     |          15 | male     | no         |
# |   0 |    1 | manage    |          15 | male     | no         |
# | 307 |  308 | admin     |          15 | male     | no         |
# | 292 |  293 | admin     |          15 | male     | no         |
# | 303 |  304 | admin     |          15 | female   | yes        |
# | 104 |  105 | admin     |          15 | male     | no         |
# | 305 |  306 | admin     |          15 | male     | no         |
# | 285 |  286 | manage    |          15 | male     | no         |
# | 298 |  299 | admin     |          15 | female   | no         |
# | 109 |  110 | admin     |          15 | male     | yes        |
# | 103 |  104 | admin     |          15 | male     | no         |
# | 287 |  288 | manage    |          15 | male     | no         |
# | 308 |  309 | admin     |          15 | male     | no         |
# | 150 |  151 | manage    |          16 | male     | no         |
# | 412 |  413 | manage    |          16 | female   | no         |
# | 433 |  434 | admin     |          16 | male     | no         |
# |  66 |   67 | manage    |          16 | male     | no         |
# | 158 |  159 | admin     |          16 | female   | yes        |
# |  20 |   21 | admin     |          16 | female   | no         |
# | 425 |  426 | admin     |          16 | male     | yes        |
# | 225 |  226 | admin     |          16 | female   | no         |
# | 299 |  300 | admin     |          16 | male     | yes        |
# | 331 |  332 | admin     |          16 | female   | no         |
# | 159 |  160 | manage    |          16 | male     | no         |
# | 216 |  217 | admin     |          16 | male     | no         |
# | 335 |  336 | manage    |          16 | male     | no         |
# |  79 |   80 | admin     |          16 | female   | no         |
# | 112 |  113 | manage    |          16 | male     | no         |
# | 204 |  205 | manage    |          16 | male     | no         |
# | 160 |  161 | admin     |          16 | male     | no         |
# | 175 |  176 | admin     |          16 | female   | no         |
# |   1 |    2 | admin     |          16 | male     | no         |
# | 100 |  101 | manage    |          16 | male     | no         |
# | 467 |  468 | manage    |          16 | female   | no         |
# | 466 |  467 | admin     |          16 | female   | no         |
# | 309 |  310 | admin     |          16 | male     | no         |
# | 317 |  318 | manage    |          16 | male     | no         |
# | 461 |  462 | manage    |          16 | female   | no         |
# |  17 |   18 | manage    |          16 | male     | no         |
# | 186 |  187 | manage    |          16 | male     | no         |
# | 306 |  307 | manage    |          16 | male     | no         |
# | 454 |  455 | manage    |          16 | male     | no         |
# | 195 |  196 | admin     |          16 | female   | yes        |
# | 448 |  449 | manage    |          16 | male     | no         |
# | 198 |  199 | manage    |          16 | male     | no         |
# | 445 |  446 | manage    |          16 | male     | yes        |
# |  10 |   11 | admin     |          16 | female   | no         |
# | 161 |  162 | manage    |          16 | male     | no         |
# | 167 |  168 | manage    |          16 | female   | no         |
# | 230 |  231 | manage    |          16 | male     | no         |
# |  78 |   79 | admin     |          16 | female   | no         |
# |  38 |   39 | admin     |          16 | male     | yes        |
# | 119 |  120 | manage    |          16 | female   | no         |
# | 370 |  371 | manage    |          16 | female   | no         |
# | 369 |  370 | admin     |          16 | female   | no         |
# | 286 |  287 | admin     |          16 | male     | no         |
# | 342 |  343 | manage    |          16 | male     | no         |
# | 133 |  134 | manage    |          16 | female   | no         |
# |  49 |   50 | manage    |          16 | male     | no         |
# |  71 |   72 | admin     |          16 | female   | no         |
# | 239 |  240 | manage    |          16 | female   | no         |
# | 265 |  266 | admin     |          16 | female   | no         |
# | 347 |  348 | manage    |          16 | female   | no         |
# | 275 |  276 | manage    |          16 | male     | no         |
# | 362 |  363 | admin     |          16 | male     | yes        |
# | 276 |  277 | manage    |          16 | female   | no         |
# |  61 |   62 | manage    |          16 | male     | no         |
# | 123 |  124 | admin     |          16 | female   | no         |
# |  63 |   64 | manage    |          16 | male     | no         |
# |  68 |   69 | manage    |          16 | male     | no         |
# |  67 |   68 | manage    |          16 | male     | no         |
# | 273 |  274 | manage    |          16 | male     | no         |
# | 382 |  383 | manage    |          17 | male     | yes        |
# | 128 |  129 | manage    |          17 | male     | no         |
# | 199 |  200 | manage    |          17 | male     | no         |
# | 380 |  381 | admin     |          17 | male     | yes        |
# | 348 |  349 | admin     |          17 | female   | no         |
# | 288 |  289 | manage    |          17 | male     | no         |
# |  96 |   97 | admin     |          17 | male     | yes        |
# |  34 |   35 | manage    |          17 | male     | no         |
# |  62 |   63 | manage    |          17 | male     | no         |
# | 405 |  406 | manage    |          17 | male     | no         |
# |  70 |   71 | manage    |          17 | male     | no         |
# |  52 |   53 | manage    |          18 | male     | no         |
# | 271 |  272 | admin     |          18 | male     | no         |
# | 289 |  290 | manage    |          18 | male     | no         |
# |  99 |  100 | manage    |          18 | male     | no         |
# | 145 |  146 | admin     |          18 | male     | yes        |
# | 327 |  328 | manage    |          18 | male     | no         |
# | 430 |  431 | manage    |          18 | male     | no         |
# | 253 |  254 | manage    |          18 | male     | no         |
# | 328 |  329 | manage    |          18 | male     | no         |
# | 102 |  103 | manage    |          19 | male     | no         |
# |  33 |   34 | manage    |          19 | male     | no         |
# | 234 |  235 | manage    |          19 | male     | no         |
# | 463 |  464 | manage    |          19 | male     | no         |
# |  26 |   27 | manage    |          19 | male     | no         |
# | 407 |  408 | manage    |          19 | male     | no         |
# | 408 |  409 | admin     |          19 | male     | no         |
# | 282 |  283 | manage    |          19 | male     | no         |
# | 231 |  232 | manage    |          19 | male     | no         |
# |  65 |   66 | manage    |          19 | male     | no         |
# |  28 |   29 | manage    |          19 | male     | no         |
# |  31 |   32 | manage    |          19 | male     | no         |
# | 457 |  458 | manage    |          19 | male     | no         |
# | 419 |  420 | manage    |          19 | male     | no         |
# | 455 |  456 | manage    |          19 | male     | no         |
# | 105 |  106 | manage    |          19 | male     | no         |
# | 453 |  454 | manage    |          19 | male     | no         |
# |  88 |   89 | manage    |          19 | male     | no         |
# | 388 |  389 | manage    |          19 | male     | no         |
# | 386 |  387 | manage    |          19 | male     | no         |
# | 449 |  450 | manage    |          19 | male     | no         |
# | 197 |  198 | manage    |          19 | male     | no         |
# | 429 |  430 | manage    |          19 | male     | yes        |
# |  87 |   88 | manage    |          19 | male     | no         |
# | 255 |  256 | manage    |          19 | male     | no         |
# | 256 |  257 | manage    |          19 | male     | no         |
# | 283 |  284 | manage    |          19 | male     | no         |
# | 129 |  130 | manage    |          20 | male     | no         |
# | 172 |  173 | manage    |          20 | male     | no         |
# | 136 |  137 | manage    |          21 | male     | no         |

# %% [markdown]
# just add the 'id' label also when sorting the values. The working of this is as follows.
# * first all the records are sorted with 'education' order, than each education order is sorted with 'id' order is ascending format.

# %%
sorted_data = data.sort_values(['education' , 'id'])

# %%
print(sorted_data.to_markdown())
# Out:
# |     |   id | job       |   education | gender   | minority   |
# |----:|-----:|:----------|------------:|:---------|:-----------|
# |   3 |    4 | admin     |           8 | female   | no         |
# |  11 |   12 | admin     |           8 | male     | yes        |
# |  35 |   36 | admin     |           8 | female   | no         |
# |  43 |   44 | admin     |           8 | male     | no         |
# |  60 |   61 | admin     |           8 | male     | yes        |
# |  64 |   65 | admin     |           8 | male     | no         |
# |  83 |   84 | admin     |           8 | female   | yes        |
# |  89 |   90 | admin     |           8 | female   | no         |
# |  91 |   92 | admin     |           8 | female   | no         |
# |  95 |   96 | custodial |           8 | male     | yes        |
# |  97 |   98 | custodial |           8 | male     | yes        |
# | 138 |  139 | admin     |           8 | female   | no         |
# | 143 |  144 | admin     |           8 | female   | no         |
# | 151 |  152 | custodial |           8 | male     | no         |
# | 173 |  174 | custodial |           8 | male     | no         |
# | 174 |  175 | admin     |           8 | male     | no         |
# | 184 |  185 | custodial |           8 | male     | no         |
# | 189 |  190 | admin     |           8 | female   | no         |
# | 208 |  209 | admin     |           8 | female   | no         |
# | 212 |  213 | custodial |           8 | male     | yes        |
# | 222 |  223 | admin     |           8 | female   | no         |
# | 235 |  236 | admin     |           8 | female   | no         |
# | 240 |  241 | admin     |           8 | female   | no         |
# | 243 |  244 | admin     |           8 | female   | no         |
# | 252 |  253 | admin     |           8 | female   | yes        |
# | 257 |  258 | admin     |           8 | male     | no         |
# | 277 |  278 | admin     |           8 | female   | no         |
# | 280 |  281 | custodial |           8 | male     | yes        |
# | 284 |  285 | custodial |           8 | male     | no         |
# | 294 |  295 | admin     |           8 | male     | no         |
# | 301 |  302 | admin     |           8 | male     | yes        |
# | 324 |  325 | admin     |           8 | female   | no         |
# | 325 |  326 | custodial |           8 | male     | yes        |
# | 334 |  335 | custodial |           8 | male     | no         |
# | 337 |  338 | admin     |           8 | female   | no         |
# | 338 |  339 | admin     |           8 | female   | no         |
# | 339 |  340 | admin     |           8 | female   | no         |
# | 351 |  352 | admin     |           8 | female   | no         |
# | 356 |  357 | admin     |           8 | female   | no         |
# | 361 |  362 | admin     |           8 | female   | no         |
# | 364 |  365 | admin     |           8 | female   | yes        |
# | 377 |  378 | admin     |           8 | female   | no         |
# | 378 |  379 | admin     |           8 | female   | no         |
# | 385 |  386 | custodial |           8 | male     | no         |
# | 393 |  394 | admin     |           8 | female   | no         |
# | 409 |  410 | admin     |           8 | female   | no         |
# | 413 |  414 | custodial |           8 | male     | yes        |
# | 426 |  427 | admin     |           8 | male     | yes        |
# | 428 |  429 | custodial |           8 | male     | yes        |
# | 436 |  437 | admin     |           8 | male     | no         |
# | 439 |  440 | admin     |           8 | female   | no         |
# | 442 |  443 | admin     |           8 | female   | no         |
# | 460 |  461 | admin     |           8 | female   | no         |
# |   2 |    3 | admin     |          12 | female   | no         |
# |   7 |    8 | admin     |          12 | female   | no         |
# |   9 |   10 | admin     |          12 | female   | no         |
# |  14 |   15 | admin     |          12 | male     | no         |
# |  15 |   16 | admin     |          12 | male     | no         |
# |  18 |   19 | admin     |          12 | male     | no         |
# |  19 |   20 | admin     |          12 | female   | no         |
# |  21 |   22 | admin     |          12 | male     | yes        |
# |  23 |   24 | admin     |          12 | female   | yes        |
# |  30 |   31 | admin     |          12 | male     | no         |
# |  36 |   37 | admin     |          12 | male     | yes        |
# |  40 |   41 | admin     |          12 | female   | yes        |
# |  42 |   43 | admin     |          12 | male     | no         |
# |  44 |   45 | custodial |          12 | male     | no         |
# |  46 |   47 | admin     |          12 | female   | no         |
# |  47 |   48 | custodial |          12 | male     | no         |
# |  50 |   51 | admin     |          12 | male     | no         |
# |  53 |   54 | admin     |          12 | male     | no         |
# |  54 |   55 | admin     |          12 | male     | no         |
# |  59 |   60 | admin     |          12 | male     | yes        |
# |  72 |   73 | admin     |          12 | female   | no         |
# |  76 |   77 | admin     |          12 | female   | no         |
# |  77 |   78 | admin     |          12 | female   | no         |
# |  80 |   81 | admin     |          12 | female   | no         |
# |  81 |   82 | admin     |          12 | female   | yes        |
# |  82 |   83 | admin     |          12 | female   | yes        |
# |  86 |   87 | admin     |          12 | male     | no         |
# |  90 |   91 | admin     |          12 | female   | no         |
# |  92 |   93 | admin     |          12 | female   | no         |
# |  93 |   94 | admin     |          12 | female   | no         |
# |  94 |   95 | admin     |          12 | female   | no         |
# |  98 |   99 | admin     |          12 | female   | yes        |
# | 106 |  107 | admin     |          12 | female   | no         |
# | 107 |  108 | admin     |          12 | female   | no         |
# | 108 |  109 | admin     |          12 | male     | yes        |
# | 110 |  111 | custodial |          12 | male     | yes        |
# | 111 |  112 | custodial |          12 | male     | yes        |
# | 116 |  117 | admin     |          12 | female   | no         |
# | 117 |  118 | admin     |          12 | female   | no         |
# | 118 |  119 | admin     |          12 | female   | no         |
# | 122 |  123 | admin     |          12 | female   | no         |
# | 124 |  125 | admin     |          12 | male     | yes        |
# | 126 |  127 | custodial |          12 | male     | yes        |
# | 127 |  128 | admin     |          12 | female   | yes        |
# | 131 |  132 | admin     |          12 | male     | no         |
# | 134 |  135 | admin     |          12 | female   | no         |
# | 135 |  136 | admin     |          12 | male     | no         |
# | 137 |  138 | admin     |          12 | male     | no         |
# | 139 |  140 | admin     |          12 | female   | no         |
# | 141 |  142 | admin     |          12 | female   | no         |
# | 142 |  143 | admin     |          12 | female   | no         |
# | 144 |  145 | admin     |          12 | male     | yes        |
# | 148 |  149 | admin     |          12 | male     | no         |
# | 149 |  150 | admin     |          12 | male     | no         |
# | 152 |  153 | admin     |          12 | female   | no         |
# | 153 |  154 | admin     |          12 | female   | no         |
# | 156 |  157 | admin     |          12 | female   | yes        |
# | 157 |  158 | admin     |          12 | female   | yes        |
# | 165 |  166 | admin     |          12 | female   | no         |
# | 166 |  167 | admin     |          12 | female   | no         |
# | 168 |  169 | admin     |          12 | male     | yes        |
# | 169 |  170 | admin     |          12 | male     | yes        |
# | 170 |  171 | admin     |          12 | male     | yes        |
# | 176 |  177 | admin     |          12 | female   | no         |
# | 177 |  178 | admin     |          12 | female   | no         |
# | 178 |  179 | admin     |          12 | male     | yes        |
# | 179 |  180 | admin     |          12 | female   | yes        |
# | 180 |  181 | admin     |          12 | female   | yes        |
# | 181 |  182 | admin     |          12 | female   | yes        |
# | 187 |  188 | admin     |          12 | female   | no         |
# | 188 |  189 | admin     |          12 | female   | no         |
# | 190 |  191 | admin     |          12 | female   | no         |
# | 191 |  192 | admin     |          12 | male     | yes        |
# | 192 |  193 | admin     |          12 | female   | yes        |
# | 194 |  195 | admin     |          12 | female   | yes        |
# | 200 |  201 | admin     |          12 | male     | no         |
# | 202 |  203 | admin     |          12 | male     | no         |
# | 205 |  206 | custodial |          12 | male     | no         |
# | 207 |  208 | admin     |          12 | female   | no         |
# | 213 |  214 | admin     |          12 | female   | yes        |
# | 214 |  215 | admin     |          12 | female   | yes        |
# | 218 |  219 | admin     |          12 | male     | no         |
# | 219 |  220 | admin     |          12 | male     | no         |
# | 220 |  221 | admin     |          12 | female   | no         |
# | 223 |  224 | admin     |          12 | female   | no         |
# | 226 |  227 | admin     |          12 | female   | no         |
# | 228 |  229 | admin     |          12 | female   | no         |
# | 236 |  237 | admin     |          12 | female   | no         |
# | 237 |  238 | admin     |          12 | female   | no         |
# | 238 |  239 | admin     |          12 | female   | no         |
# | 241 |  242 | admin     |          12 | female   | no         |
# | 242 |  243 | admin     |          12 | female   | no         |
# | 244 |  245 | admin     |          12 | female   | no         |
# | 245 |  246 | admin     |          12 | female   | no         |
# | 246 |  247 | admin     |          12 | female   | no         |
# | 247 |  248 | admin     |          12 | female   | no         |
# | 248 |  249 | admin     |          12 | female   | no         |
# | 250 |  251 | admin     |          12 | female   | no         |
# | 251 |  252 | admin     |          12 | male     | yes        |
# | 254 |  255 | custodial |          12 | male     | no         |
# | 258 |  259 | admin     |          12 | female   | no         |
# | 259 |  260 | admin     |          12 | female   | no         |
# | 260 |  261 | admin     |          12 | female   | no         |
# | 261 |  262 | admin     |          12 | female   | no         |
# | 262 |  263 | admin     |          12 | female   | no         |
# | 263 |  264 | admin     |          12 | female   | no         |
# | 264 |  265 | admin     |          12 | female   | no         |
# | 266 |  267 | admin     |          12 | female   | no         |
# | 267 |  268 | admin     |          12 | male     | yes        |
# | 272 |  273 | custodial |          12 | male     | no         |
# | 274 |  275 | admin     |          12 | male     | no         |
# | 278 |  279 | admin     |          12 | female   | no         |
# | 279 |  280 | admin     |          12 | female   | no         |
# | 290 |  291 | custodial |          12 | male     | no         |
# | 293 |  294 | admin     |          12 | male     | no         |
# | 295 |  296 | admin     |          12 | male     | no         |
# | 296 |  297 | admin     |          12 | female   | no         |
# | 297 |  298 | admin     |          12 | female   | no         |
# | 300 |  301 | admin     |          12 | male     | yes        |
# | 302 |  303 | custodial |          12 | male     | yes        |
# | 304 |  305 | custodial |          12 | male     | no         |
# | 310 |  311 | admin     |          12 | female   | no         |
# | 311 |  312 | admin     |          12 | female   | no         |
# | 312 |  313 | admin     |          12 | female   | no         |
# | 313 |  314 | admin     |          12 | female   | no         |
# | 314 |  315 | admin     |          12 | female   | no         |
# | 316 |  317 | admin     |          12 | male     | yes        |
# | 319 |  320 | admin     |          12 | male     | no         |
# | 320 |  321 | admin     |          12 | female   | no         |
# | 321 |  322 | admin     |          12 | female   | no         |
# | 323 |  324 | admin     |          12 | female   | no         |
# | 326 |  327 | admin     |          12 | male     | yes        |
# | 330 |  331 | admin     |          12 | female   | no         |
# | 333 |  334 | admin     |          12 | female   | yes        |
# | 336 |  337 | admin     |          12 | female   | no         |
# | 340 |  341 | manage    |          12 | male     | yes        |
# | 341 |  342 | admin     |          12 | female   | yes        |
# | 343 |  344 | admin     |          12 | male     | no         |
# | 344 |  345 | admin     |          12 | female   | no         |
# | 346 |  347 | admin     |          12 | female   | no         |
# | 349 |  350 | admin     |          12 | female   | no         |
# | 350 |  351 | admin     |          12 | female   | no         |
# | 352 |  353 | custodial |          12 | male     | yes        |
# | 353 |  354 | admin     |          12 | female   | yes        |
# | 358 |  359 | admin     |          12 | female   | no         |
# | 359 |  360 | admin     |          12 | female   | no         |
# | 360 |  361 | admin     |          12 | female   | no         |
# | 363 |  364 | admin     |          12 | female   | yes        |
# | 365 |  366 | admin     |          12 | female   | yes        |
# | 366 |  367 | admin     |          12 | female   | yes        |
# | 367 |  368 | admin     |          12 | female   | yes        |
# | 372 |  373 | admin     |          12 | male     | no         |
# | 374 |  375 | admin     |          12 | male     | no         |
# | 379 |  380 | admin     |          12 | female   | no         |
# | 381 |  382 | admin     |          12 | male     | yes        |
# | 383 |  384 | admin     |          12 | female   | yes        |
# | 384 |  385 | custodial |          12 | male     | no         |
# | 390 |  391 | admin     |          12 | female   | no         |
# | 391 |  392 | admin     |          12 | female   | no         |
# | 392 |  393 | admin     |          12 | female   | no         |
# | 394 |  395 | admin     |          12 | female   | no         |
# | 395 |  396 | admin     |          12 | female   | no         |
# | 396 |  397 | admin     |          12 | female   | no         |
# | 397 |  398 | admin     |          12 | female   | no         |
# | 398 |  399 | admin     |          12 | female   | no         |
# | 399 |  400 | admin     |          12 | female   | no         |
# | 400 |  401 | admin     |          12 | female   | no         |
# | 401 |  402 | admin     |          12 | female   | no         |
# | 402 |  403 | admin     |          12 | female   | yes        |
# | 403 |  404 | admin     |          12 | female   | yes        |
# | 404 |  405 | admin     |          12 | female   | yes        |
# | 410 |  411 | admin     |          12 | female   | no         |
# | 411 |  412 | admin     |          12 | female   | no         |
# | 422 |  423 | admin     |          12 | female   | no         |
# | 424 |  425 | admin     |          12 | female   | no         |
# | 431 |  432 | admin     |          12 | male     | no         |
# | 432 |  433 | admin     |          12 | male     | no         |
# | 435 |  436 | admin     |          12 | male     | no         |
# | 438 |  439 | admin     |          12 | female   | no         |
# | 441 |  442 | admin     |          12 | female   | no         |
# | 443 |  444 | admin     |          12 | female   | no         |
# | 447 |  448 | admin     |          12 | female   | yes        |
# | 451 |  452 | admin     |          12 | male     | no         |
# | 458 |  459 | admin     |          12 | female   | no         |
# | 459 |  460 | admin     |          12 | female   | no         |
# | 464 |  465 | admin     |          12 | male     | no         |
# | 465 |  466 | admin     |          12 | female   | no         |
# | 469 |  470 | admin     |          12 | male     | yes        |
# | 472 |  473 | admin     |          12 | female   | no         |
# | 473 |  474 | admin     |          12 | female   | no         |
# | 101 |  102 | admin     |          14 | male     | no         |
# | 113 |  114 | admin     |          14 | male     | no         |
# | 281 |  282 | admin     |          14 | male     | yes        |
# | 291 |  292 | admin     |          14 | male     | no         |
# | 368 |  369 | admin     |          14 | male     | no         |
# | 387 |  388 | admin     |          14 | male     | no         |
# |   0 |    1 | manage    |          15 | male     | no         |
# |   4 |    5 | admin     |          15 | male     | no         |
# |   5 |    6 | admin     |          15 | male     | no         |
# |   6 |    7 | admin     |          15 | male     | no         |
# |   8 |    9 | admin     |          15 | female   | no         |
# |  12 |   13 | admin     |          15 | male     | yes        |
# |  13 |   14 | admin     |          15 | female   | yes        |
# |  16 |   17 | admin     |          15 | male     | no         |
# |  22 |   23 | admin     |          15 | female   | yes        |
# |  24 |   25 | admin     |          15 | female   | yes        |
# |  25 |   26 | admin     |          15 | male     | no         |
# |  27 |   28 | admin     |          15 | male     | no         |
# |  29 |   30 | admin     |          15 | male     | no         |
# |  32 |   33 | admin     |          15 | male     | no         |
# |  37 |   38 | admin     |          15 | male     | yes        |
# |  39 |   40 | admin     |          15 | female   | yes        |
# |  41 |   42 | admin     |          15 | male     | no         |
# |  45 |   46 | admin     |          15 | female   | no         |
# |  48 |   49 | admin     |          15 | male     | no         |
# |  51 |   52 | admin     |          15 | male     | no         |
# |  55 |   56 | admin     |          15 | male     | no         |
# |  56 |   57 | admin     |          15 | male     | no         |
# |  57 |   58 | admin     |          15 | female   | no         |
# |  58 |   59 | admin     |          15 | male     | yes        |
# |  69 |   70 | admin     |          15 | male     | no         |
# |  73 |   74 | admin     |          15 | female   | no         |
# |  74 |   75 | admin     |          15 | female   | no         |
# |  75 |   76 | admin     |          15 | female   | no         |
# |  84 |   85 | admin     |          15 | male     | no         |
# |  85 |   86 | admin     |          15 | male     | no         |
# | 103 |  104 | admin     |          15 | male     | no         |
# | 104 |  105 | admin     |          15 | male     | no         |
# | 109 |  110 | admin     |          15 | male     | yes        |
# | 114 |  115 | admin     |          15 | male     | no         |
# | 115 |  116 | admin     |          15 | male     | no         |
# | 120 |  121 | admin     |          15 | female   | no         |
# | 121 |  122 | admin     |          15 | female   | no         |
# | 125 |  126 | custodial |          15 | male     | yes        |
# | 130 |  131 | admin     |          15 | male     | no         |
# | 132 |  133 | admin     |          15 | male     | no         |
# | 140 |  141 | admin     |          15 | female   | no         |
# | 146 |  147 | admin     |          15 | male     | yes        |
# | 147 |  148 | admin     |          15 | female   | yes        |
# | 154 |  155 | admin     |          15 | male     | yes        |
# | 155 |  156 | admin     |          15 | male     | yes        |
# | 162 |  163 | admin     |          15 | male     | no         |
# | 163 |  164 | admin     |          15 | female   | no         |
# | 164 |  165 | admin     |          15 | female   | no         |
# | 171 |  172 | admin     |          15 | female   | yes        |
# | 182 |  183 | admin     |          15 | male     | no         |
# | 183 |  184 | admin     |          15 | male     | no         |
# | 185 |  186 | admin     |          15 | male     | no         |
# | 193 |  194 | admin     |          15 | female   | yes        |
# | 196 |  197 | manage    |          15 | male     | no         |
# | 201 |  202 | admin     |          15 | male     | no         |
# | 203 |  204 | admin     |          15 | male     | no         |
# | 206 |  207 | admin     |          15 | male     | no         |
# | 209 |  210 | admin     |          15 | male     | yes        |
# | 210 |  211 | admin     |          15 | male     | yes        |
# | 211 |  212 | admin     |          15 | male     | yes        |
# | 215 |  216 | admin     |          15 | male     | no         |
# | 217 |  218 | admin     |          15 | male     | no         |
# | 221 |  222 | admin     |          15 | female   | no         |
# | 224 |  225 | admin     |          15 | female   | no         |
# | 227 |  228 | admin     |          15 | female   | no         |
# | 229 |  230 | admin     |          15 | male     | yes        |
# | 232 |  233 | admin     |          15 | male     | no         |
# | 233 |  234 | admin     |          15 | male     | no         |
# | 249 |  250 | admin     |          15 | female   | no         |
# | 268 |  269 | admin     |          15 | male     | no         |
# | 269 |  270 | admin     |          15 | male     | no         |
# | 270 |  271 | admin     |          15 | male     | no         |
# | 285 |  286 | manage    |          15 | male     | no         |
# | 287 |  288 | manage    |          15 | male     | no         |
# | 292 |  293 | admin     |          15 | male     | no         |
# | 298 |  299 | admin     |          15 | female   | no         |
# | 303 |  304 | admin     |          15 | female   | yes        |
# | 305 |  306 | admin     |          15 | male     | no         |
# | 307 |  308 | admin     |          15 | male     | no         |
# | 308 |  309 | admin     |          15 | male     | no         |
# | 315 |  316 | admin     |          15 | male     | yes        |
# | 318 |  319 | admin     |          15 | male     | no         |
# | 322 |  323 | admin     |          15 | female   | no         |
# | 329 |  330 | admin     |          15 | male     | no         |
# | 332 |  333 | admin     |          15 | female   | no         |
# | 345 |  346 | admin     |          15 | female   | no         |
# | 354 |  355 | admin     |          15 | male     | no         |
# | 355 |  356 | admin     |          15 | male     | no         |
# | 357 |  358 | admin     |          15 | female   | no         |
# | 371 |  372 | admin     |          15 | male     | no         |
# | 373 |  374 | admin     |          15 | male     | no         |
# | 375 |  376 | admin     |          15 | male     | no         |
# | 376 |  377 | admin     |          15 | male     | no         |
# | 389 |  390 | admin     |          15 | female   | no         |
# | 406 |  407 | admin     |          15 | male     | no         |
# | 414 |  415 | admin     |          15 | male     | yes        |
# | 415 |  416 | admin     |          15 | male     | no         |
# | 416 |  417 | admin     |          15 | male     | no         |
# | 417 |  418 | admin     |          15 | male     | no         |
# | 418 |  419 | admin     |          15 | male     | no         |
# | 420 |  421 | admin     |          15 | male     | no         |
# | 421 |  422 | admin     |          15 | male     | no         |
# | 423 |  424 | admin     |          15 | female   | no         |
# | 427 |  428 | admin     |          15 | male     | yes        |
# | 434 |  435 | admin     |          15 | male     | no         |
# | 437 |  438 | admin     |          15 | male     | no         |
# | 440 |  441 | admin     |          15 | female   | no         |
# | 444 |  445 | admin     |          15 | male     | yes        |
# | 446 |  447 | admin     |          15 | male     | yes        |
# | 450 |  451 | admin     |          15 | male     | no         |
# | 452 |  453 | admin     |          15 | male     | no         |
# | 456 |  457 | admin     |          15 | male     | no         |
# | 462 |  463 | admin     |          15 | female   | no         |
# | 468 |  469 | admin     |          15 | female   | no         |
# | 470 |  471 | admin     |          15 | male     | yes        |
# | 471 |  472 | admin     |          15 | male     | no         |
# |   1 |    2 | admin     |          16 | male     | no         |
# |  10 |   11 | admin     |          16 | female   | no         |
# |  17 |   18 | manage    |          16 | male     | no         |
# |  20 |   21 | admin     |          16 | female   | no         |
# |  38 |   39 | admin     |          16 | male     | yes        |
# |  49 |   50 | manage    |          16 | male     | no         |
# |  61 |   62 | manage    |          16 | male     | no         |
# |  63 |   64 | manage    |          16 | male     | no         |
# |  66 |   67 | manage    |          16 | male     | no         |
# |  67 |   68 | manage    |          16 | male     | no         |
# |  68 |   69 | manage    |          16 | male     | no         |
# |  71 |   72 | admin     |          16 | female   | no         |
# |  78 |   79 | admin     |          16 | female   | no         |
# |  79 |   80 | admin     |          16 | female   | no         |
# | 100 |  101 | manage    |          16 | male     | no         |
# | 112 |  113 | manage    |          16 | male     | no         |
# | 119 |  120 | manage    |          16 | female   | no         |
# | 123 |  124 | admin     |          16 | female   | no         |
# | 133 |  134 | manage    |          16 | female   | no         |
# | 150 |  151 | manage    |          16 | male     | no         |
# | 158 |  159 | admin     |          16 | female   | yes        |
# | 159 |  160 | manage    |          16 | male     | no         |
# | 160 |  161 | admin     |          16 | male     | no         |
# | 161 |  162 | manage    |          16 | male     | no         |
# | 167 |  168 | manage    |          16 | female   | no         |
# | 175 |  176 | admin     |          16 | female   | no         |
# | 186 |  187 | manage    |          16 | male     | no         |
# | 195 |  196 | admin     |          16 | female   | yes        |
# | 198 |  199 | manage    |          16 | male     | no         |
# | 204 |  205 | manage    |          16 | male     | no         |
# | 216 |  217 | admin     |          16 | male     | no         |
# | 225 |  226 | admin     |          16 | female   | no         |
# | 230 |  231 | manage    |          16 | male     | no         |
# | 239 |  240 | manage    |          16 | female   | no         |
# | 265 |  266 | admin     |          16 | female   | no         |
# | 273 |  274 | manage    |          16 | male     | no         |
# | 275 |  276 | manage    |          16 | male     | no         |
# | 276 |  277 | manage    |          16 | female   | no         |
# | 286 |  287 | admin     |          16 | male     | no         |
# | 299 |  300 | admin     |          16 | male     | yes        |
# | 306 |  307 | manage    |          16 | male     | no         |
# | 309 |  310 | admin     |          16 | male     | no         |
# | 317 |  318 | manage    |          16 | male     | no         |
# | 331 |  332 | admin     |          16 | female   | no         |
# | 335 |  336 | manage    |          16 | male     | no         |
# | 342 |  343 | manage    |          16 | male     | no         |
# | 347 |  348 | manage    |          16 | female   | no         |
# | 362 |  363 | admin     |          16 | male     | yes        |
# | 369 |  370 | admin     |          16 | female   | no         |
# | 370 |  371 | manage    |          16 | female   | no         |
# | 412 |  413 | manage    |          16 | female   | no         |
# | 425 |  426 | admin     |          16 | male     | yes        |
# | 433 |  434 | admin     |          16 | male     | no         |
# | 445 |  446 | manage    |          16 | male     | yes        |
# | 448 |  449 | manage    |          16 | male     | no         |
# | 454 |  455 | manage    |          16 | male     | no         |
# | 461 |  462 | manage    |          16 | female   | no         |
# | 466 |  467 | admin     |          16 | female   | no         |
# | 467 |  468 | manage    |          16 | female   | no         |
# |  34 |   35 | manage    |          17 | male     | no         |
# |  62 |   63 | manage    |          17 | male     | no         |
# |  70 |   71 | manage    |          17 | male     | no         |
# |  96 |   97 | admin     |          17 | male     | yes        |
# | 128 |  129 | manage    |          17 | male     | no         |
# | 199 |  200 | manage    |          17 | male     | no         |
# | 288 |  289 | manage    |          17 | male     | no         |
# | 348 |  349 | admin     |          17 | female   | no         |
# | 380 |  381 | admin     |          17 | male     | yes        |
# | 382 |  383 | manage    |          17 | male     | yes        |
# | 405 |  406 | manage    |          17 | male     | no         |
# |  52 |   53 | manage    |          18 | male     | no         |
# |  99 |  100 | manage    |          18 | male     | no         |
# | 145 |  146 | admin     |          18 | male     | yes        |
# | 253 |  254 | manage    |          18 | male     | no         |
# | 271 |  272 | admin     |          18 | male     | no         |
# | 289 |  290 | manage    |          18 | male     | no         |
# | 327 |  328 | manage    |          18 | male     | no         |
# | 328 |  329 | manage    |          18 | male     | no         |
# | 430 |  431 | manage    |          18 | male     | no         |
# |  26 |   27 | manage    |          19 | male     | no         |
# |  28 |   29 | manage    |          19 | male     | no         |
# |  31 |   32 | manage    |          19 | male     | no         |
# |  33 |   34 | manage    |          19 | male     | no         |
# |  65 |   66 | manage    |          19 | male     | no         |
# |  87 |   88 | manage    |          19 | male     | no         |
# |  88 |   89 | manage    |          19 | male     | no         |
# | 102 |  103 | manage    |          19 | male     | no         |
# | 105 |  106 | manage    |          19 | male     | no         |
# | 197 |  198 | manage    |          19 | male     | no         |
# | 231 |  232 | manage    |          19 | male     | no         |
# | 234 |  235 | manage    |          19 | male     | no         |
# | 255 |  256 | manage    |          19 | male     | no         |
# | 256 |  257 | manage    |          19 | male     | no         |
# | 282 |  283 | manage    |          19 | male     | no         |
# | 283 |  284 | manage    |          19 | male     | no         |
# | 386 |  387 | manage    |          19 | male     | no         |
# | 388 |  389 | manage    |          19 | male     | no         |
# | 407 |  408 | manage    |          19 | male     | no         |
# | 408 |  409 | admin     |          19 | male     | no         |
# | 419 |  420 | manage    |          19 | male     | no         |
# | 429 |  430 | manage    |          19 | male     | yes        |
# | 449 |  450 | manage    |          19 | male     | no         |
# | 453 |  454 | manage    |          19 | male     | no         |
# | 455 |  456 | manage    |          19 | male     | no         |
# | 457 |  458 | manage    |          19 | male     | no         |
# | 463 |  464 | manage    |          19 | male     | no         |
# | 129 |  130 | manage    |          20 | male     | no         |
# | 172 |  173 | manage    |          20 | male     | no         |
# | 136 |  137 | manage    |          21 | male     | no         |

# %% [markdown]
# **further you can also add more columns(labels) when sorting**
# * for example, sorted_data = data.sort_values(['education' , 'id' , 'another_column'])
# the above code now will sort the data further, according to the 'another_column' values.
#
# **you can understand this just by a simple example, first you sort the data in group of contents, accordance to a target value(first column, example -> 'education').
# when you are done sorting you will have one or more than one groups.
# so now you sort these groups in accordance to another target value(second column, example -> 'id').
# Now you made further more groups of data, because you are sorting the data in chunks.
# So you can further sort these groups of data in accordance to another target value(third column -> 'another_column').
# Finally, the chunks of data are aggregated into one table, according to sorting order of last target variable, in this case it is 'another_column'**

# %% [markdown]
# ## Group By

# %% [markdown]
# Group by clause is used to select and organize the data into groups, for example if we take the example of our data.
# if we check all the unique values of label 'education'.

# %%
sorted_data['education'].unique()
# Out:
# array([ 8, 12, 14, 15, 16, 17, 18, 19, 20, 21])

# %% [markdown]
# The above values are all the unique values of 'education' in the data. this shows, if we apply group by with target value as 'education' we will have total of groups equal to the number of unique values of target variable.
# now lets verify this.

# %% [markdown]
# **grouping the data on 'education'**

# %%
group_by_education = sorted_data.groupby('education')

# %%
type(group_by_education)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# **group by function returns a key dictionary so we cant visualize it using to_markdown() or display(). we have to use first(). this funtion return the key of each group. and the first record attached to that particular key,  of course thier are multiple records attached to each key. they are just hidden(not visualized)**

# %%
# print(group_by_education.to_markdown())
# display(group_by_education)
group_by_education.first()
# Out:
#             id     job  gender minority
# education
# 8            4   admin  female       no
# 12           3   admin  female       no
# 14         102   admin    male       no
# 15           1  manage    male       no
# 16           2   admin    male       no
# 17          35  manage    male       no
# 18          53  manage    male       no
# 19          27  manage    male       no
# 20         130  manage    male       no
# 21         137  manage    male       no

# %%
keys = group_by_education.groups.keys()
print(len(keys))
# Out:
# 10

# %%
print(keys)
# Out:
# dict_keys([8, 12, 14, 15, 16, 17, 18, 19, 20, 21])

# %%
sorted_data['education'].unique()
# Out:
# array([ 8, 12, 14, 15, 16, 17, 18, 19, 20, 21])

# %%
print(len(sorted_data['education'].unique()))
# Out:
# 10

# %% [markdown]
# as you can see above groups are equal to the number of unique value in target variable.
#
# **'group by' turned the data into groups, so now we can apply aggregation fucntion to each group to get more insights, such as count of each group, sum, disjoints, left joints, inner joins etc.**

# %% [markdown]
# **but before all of this, we need to access the groups and the records in each group.**

# %%
# used to convert data into an array before appending it into a list.
import numpy as np

# creating a data list where we store our key-values
data_list = []
# for each key store the corresponding data.
for i in keys:
    education = i 
    groups = group_by_education.get_group(education)
#     print(type(groups))
    groups = np.asarray(groups)
    data_list.append(groups)

# %%
# the lenght of list should be equal to the number of groups. 
print(len(data_list))
# Out:
# 10

# %% [markdown]
# **now we have data in groups so lets just count the number of records in reach group.**

# %%
# enumerate loop is best for working with iteratable data types of python. 
# it lets you iterate with index and index value.

# used to store the count value of each group
total_number_of_records_group_wise = []

for idx , val in enumerate(data_list):
#     print(idx)
#     print(val)

    # each group is at each index, at each index is a list.
    # so by calcualting the lenght of each index list we get the total number of records in each group.
    total_number_of_records_in_a_group = len(val)
    total_number_of_records_group_wise.append(total_number_of_records_in_a_group)

# %% [markdown]
# **record count of each group.**

# %%
print(total_number_of_records_group_wise)
# Out:
# [53, 190, 6, 116, 59, 11, 9, 27, 2, 1]

# %% [markdown]
# **summation of record count of each group, should be equal to the total number of records in the dataset.**

# %%
print(sum(total_number_of_records_group_wise))
# Out:
# 474

# %%
len(data)
# Out:
# 474
